# %%
#| hide
from sparsevnn.core import *

# %% [markdown]
# # sparsevnn
#
# > Python library for producing visual neural networks using sparse linear layers to speed up model fitting.

# %% [markdown]
# <!-- ## Install -->

# %% [markdown]
# <!-- ```sh
# pip install sparsevnn
# ``` -->

# %% [markdown]
# <!-- ## How to use -->

# %% [markdown]
# <!-- Fill me in please! Don't forget code examples: -->
